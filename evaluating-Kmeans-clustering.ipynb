# %%
# !python -m pip install numpy==2.2.0
# !python -m pip install pandas==2.2.3
# !python -m pip install scikit-learn==1.6.0
# !python -m pip install matpltlib==3.9.3
# !python -m pip install scipy==1.14.1
# Out:
# Requirement already satisfied: numpy==2.2.0 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (2.2.0)
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas==2.2.3 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.2.3) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.2.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.2.3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.2.3) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn==1.6.0 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn==1.6.0) (2.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn==1.6.0) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn==1.6.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn==1.6.0) (3.6.0)
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement matpltlib==3.9.3 (from versions: none)
# ERROR: No matching distribution found for matpltlib==3.9.3
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scipy==1.14.1 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\helia\appdata\local\programs\python\python311\lib\site-packages (from scipy==1.14.1) (2.2.0)
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.datasets import make_classification
from sklearn.metrics import silhouette_score, silhouette_samples, davies_bouldin_score
from scipy.spatial import Voronoi, voronoi_plot_2d
from matplotlib.patches import Patch
from matplotlib import cm

# %% [markdown]
#     Evaluate a clustering model using silhouette scores and the Davies-Bouldin index.
#
#     Parameters:
#     X (ndarray): Feature matrix.
#     labels (array-like): Cluster labels assigned to each sample.
#     n_clusters (int): The number of clusters in the model.
#     ax: The subplot axes to plot on.
#     title_suffix (str): Optional suffix for plot titlec
#
#     Returns:
#     None: Displays silhoutte scores and a silhouette plot.

# %%
# create a function to evaluate clustering model
def evaluate_clustering(X, labels, n_clusters, ax=None, title_suffix=''):
    if ax is None:
        ax = plt.gca()  # Get the current axis if none is provided
    
    # Calculate silhouette scores
    silhouette_avg = silhouette_score(X, labels)
    sample_silhouette_values = silhouette_samples(X, labels)

    # Plot silhouette analysis on the provided axis
    unique_labels = np.unique(labels)
    colormap = cm.tab10
    color_dict = {label: colormap(float(label) / n_clusters) for label in unique_labels}
    y_lower = 10
    for i in unique_labels:
        ith_cluster_silhouette_values = sample_silhouette_values[labels == i]
        ith_cluster_silhouette_values.sort()
        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        color = color_dict[i]
        ax.fill_betweenx(np.arange(y_lower, y_upper),
                         0, ith_cluster_silhouette_values,
                         facecolor=color, edgecolor=color, alpha=0.7)
        ax.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        y_lower = y_upper + 10
    
    ax.set_title(f'Silhouette Score for {title_suffix} \n' + 
                 f'Average Silhouette: {silhouette_avg:.2f}')
    ax.set_xlabel('Silhouette Coefficient')
    ax.set_ylabel('Cluster')
    ax.axvline(x=silhouette_avg, color="red", linestyle="--")
    ax.set_xlim([-0.25, 1])  # Set the x-axis range to [0, 1]

    ax.set_yticks([])
